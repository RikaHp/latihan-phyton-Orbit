# %% [markdown]
# <a href="https://colab.research.google.com/github/RikaHp/latihan-phyton-Orbit/blob/main/Salinan_dari_Assessment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Soal 1 (Container)

# %%
A = {6, 9,7,8}
B = {1,9,7,2}
C = {2,7,8,5,0,4}
D = {0,4,3}

#A irisan B
irisan = A.intersection(B)
print(A.intersection(B))

#B gabungan C
gabungan = B.union(C)
print(B.union(C))

#C beda setangkup D
beda = C.difference(D)
print(C.difference(D))
# Out:
# {9, 7}
# {0, 1, 2, 4, 5, 7, 8, 9}
# {8, 2, 5, 7}

# %% [markdown]
# Representasikan himpunan matematika berikut ke dalam bentuk set! Kemudian carilah:
# - A irisan B
# - B gabungan C
# - C beda setangkup D
#
# ![set0 (2).png](data:image/png;base64,...)

# %% [markdown]
# # Soal 2 (Container)

# %% [markdown]
# Buat sebuah ndarray dengan elemen seperti gambar di bawah!
#
# Kemudian lakukan slicing pada ndarray tersebut sesuai dengan arahan kotak merah!
#
# **Pilih 3 saja!**
#
# ![slicing4.png](data:image/png;base64,...)

# %% [markdown]
# # Soal 3 (Flow Control)

# %% [markdown]
# Buatlah program untuk menentukan status berat badan berdasarkan Body Mass Index (BMI)!
#
# BMI = berat badan (kg) / (tinggi badan (m))²
#
# Status berat badan berdasarkan BMI:
#
# ![bmi.png](data:image/png;base64,...)
#
# ![Screenshot 2024-09-17 101808.png](data:image/png;base64,...)

# %% [markdown]
# # Soal 4 (Flow Control)

# %% [markdown]
# Buatlah program yang dapat memisahkan nilai berikut ke dalam list yang sesuai dengan menggunakan conditionals dan loops!
#
# ![soal flowcontrol 2.PNG](data:image/png;base64,...)
#
#
# <br>
#
# Rules pemisahan nilai adalah sebagai berikut:
#
# ![soal flowcontrol 22 (1).png](data:image/png;base64,...)
#
# <br>
#
# Contoh output program:
#
#
# ![soal flowcontrol 23.PNG](data:image/png;base64,...)

# %% [markdown]
# # Soal 5 (Function)

# %% [markdown]
# Sebuah perusahaan meminta Anda membuat sebuah program untuk menghitung upah bersih karyawan mereka. Berikut adalah sistem pengupahan di perusahaan tersebut:
#
# ![pengupahan (1).png](data:image/png;base64,...)
#
#
# Program harus mengimplementasikan konsep function yang memanggil function lainnya (*divide and conquer*)! Jangan lupa tambahkan dokumentasi di dalam function menggunakan docstring!
#
# Lalu, hitunglah upah bersih karyawan berikut ini menggunakan program yang telah dibuat:
#
# ![karyawan (2).png](data:image/png;base64,...)
